# %%
total = 7
total
# Out:
# 7

# %%
total- 2
# Out:
# 5

# %%
total = 10
total
# Out:
# 10

# %%
total= total - 2 * 5
total
# Out:
# -20

# %%
x = 10
y = 20
z = 31

print(x + y * z)
print(x - y * z)
# Out:
# 630
# -610

# %%
tiggy = 10
otto = 34

tiggy + otto
# Out:
# 44

# %%
x = 7
y = -2
z = 5

# %%
3 * x  * (4 + y)
# Out:
# 42

# %%
-y - (x + 3) / z
# Out:
# 0.0
